# %% [markdown]
# # Session 6: Narrative Layer and Full Pipeline
#
# This notebook turns structured explanation sentences into short narrative summaries. It connects the full pipeline from data preparation and forecasting to fuzzy labels, structured explanations, and final human-readable output.
#
# The goal is to produce a clean end-to-end MVP.

# %%
import pandas as pd

explanations = pd.read_csv("data/session05_structured_explanations.csv")
explanations
# Out:
#      Model       MAE      RMSE    MAPE     MPE   MAE_Label  \
# 0  Prophet  1404.140  1803.539   9.485  -2.578   low error
# 1      ETS  2711.084  3479.820  16.798  14.997  high error
#
#                 MPE_Label                     Combined_Label  \
# 0  slight underprediction  low error, slight underprediction
# 1   slight overprediction  high error, slight overprediction
#
#                               Structured_Explanation
# 0  The model is accurate overall and slightly con...
# 1  The model has high error and tends to overpred...

# %%
def narrative_summary(model, mae_label, mpe_label, structured_text):
    if mae_label == "low error" and mpe_label == "slight underprediction":
        return (
            f"{model} performs well overall. "
            f"{structured_text} "
            "This suggests the model tracks demand closely while staying slightly conservative."
        )
    if mae_label == "high error" and mpe_label == "slight overprediction":
        return (
            f"{model} is weaker than the other model. "
            f"{structured_text} "
            "This suggests the forecasts are less accurate and tend to run a little above actual demand."
        )
    if mae_label == "medium error":
        return (
            f"{model} shows moderate performance. "
            f"{structured_text} "
            "This suggests the model is useful, but still leaves room for improvement."
        )
    return f"{model} shows {mae_label} and {mpe_label}. {structured_text}"

# %%
explanations["Narrative"] = explanations.apply(
    lambda r: narrative_summary(
        r["Model"],
        r["MAE_Label"],
        r["MPE_Label"],
        r["Structured_Explanation"]
    ),
    axis=1
)

explanations[["Model", "Structured_Explanation", "Narrative"]]
# Out:
#      Model                             Structured_Explanation  \
# 0  Prophet  The model is accurate overall and slightly con...
# 1      ETS  The model has high error and tends to overpred...
#
#                                            Narrative
# 0  Prophet performs well overall. The model is ac...
# 1  ETS is weaker than the other model. The model ...

# %%
for _, row in explanations.iterrows():
    print(row["Narrative"])
    print()
# Out:
# Prophet performs well overall. The model is accurate overall and slightly conservative in its forecasts. This suggests the model tracks demand closely while staying slightly conservative.
#
# ETS is weaker than the other model. The model has high error and tends to overpredict demand. This suggests the forecasts are less accurate and tend to run a little above actual demand.

# %%
explanations.to_csv("data/session06_narratives.csv", index=False)
