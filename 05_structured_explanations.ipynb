# %% [markdown]
# # Session 5: Rules and Structured Explanations
#
# This notebook turns fuzzy metric labels into short structured explanations.
#
# It sits between the fuzzy labeling step and the final narrative layer by translating labels such as “low error” or “slight overprediction” into human-readable rule outputs.
#
# The goal is not to build a complex natural-language system. Instead, the notebook uses a few simple rules to generate consistent explanation sentences that can later be turned into a short narrative summary.

# %%
import pandas as pd

metrics = pd.read_csv("data/session04_fuzzy_labels.csv")

# %% [markdown]
# ### Rule Function

# %%
def structured_explanation(mae_label, mpe_label):
    if mae_label == "low error" and mpe_label == "slight underprediction":
        return "The model is accurate overall and slightly conservative in its forecasts."
    if mae_label == "low error" and mpe_label == "neutral":
        return "The model is accurate overall and shows little directional bias."
    if mae_label == "medium error" and mpe_label == "slight underprediction":
        return "The model has moderate error and slightly underpredicts demand."
    if mae_label == "medium error" and mpe_label == "slight overprediction":
        return "The model has moderate error and slightly overpredicts demand."
    if mae_label == "high error" and mpe_label == "slight underprediction":
        return "The model has high error and tends to underpredict demand."
    if mae_label == "high error" and mpe_label == "slight overprediction":
        return "The model has high error and tends to overpredict demand."
    return f"The model shows {mae_label} and {mpe_label}."

# %%
metrics["Structured_Explanation"] = metrics.apply(
    lambda r: structured_explanation(r["MAE_Label"], r["MPE_Label"]),
    axis=1
)

metrics
# Out:
#      Model       MAE      RMSE    MAPE     MPE   MAE_Label  \
# 0  Prophet  1404.140  1803.539   9.485  -2.578   low error
# 1      ETS  2711.084  3479.820  16.798  14.997  high error
#
#                 MPE_Label                     Combined_Label  \
# 0  slight underprediction  low error, slight underprediction
# 1   slight overprediction  high error, slight overprediction
#
#                               Structured_Explanation
# 0  The model is accurate overall and slightly con...
# 1  The model has high error and tends to overpred...

# %%
for _, row in metrics.iterrows():
    print(f"{row['Model']}: {row['Structured_Explanation']}")
# Out:
# Prophet: The model is accurate overall and slightly conservative in its forecasts.
# ETS: The model has high error and tends to overpredict demand.

# %%
metrics.to_csv("data/session05_structured_explanations.csv", index=False)

# %% [markdown]
# These rules are intentionally short and interpretable. They convert fuzzy labels into structured statements that describe both the size of the forecasting error and the direction of any bias.
