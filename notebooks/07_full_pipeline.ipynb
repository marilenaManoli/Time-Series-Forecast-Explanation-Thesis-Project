# %% [markdown]
# # Session 7: Full Pipeline Connection
#
# This notebook connects the outputs from Sessions 1–6 into one place.
#
# It does not rebuild the models, instead it loads the saved outputs from each step and shows the complete pipeline from cleaned data to final narrative explanation.

# %%
import pandas as pd

# %% [markdown]
# ### Session 1 output: cleaned data

# %%
cleaned_df = pd.read_csv("../src/data/cleaned_aep_hourly.csv", parse_dates=["Datetime"])
cleaned_df.head()
# Out:
#              Datetime   AEP_MW
# 0 2004-10-01 01:00:00  12379.0
# 1 2004-10-01 02:00:00  11935.0
# 2 2004-10-01 03:00:00  11692.0
# 3 2004-10-01 04:00:00  11597.0
# 4 2004-10-01 05:00:00  11681.0

# %% [markdown]
# ### Session 2 outputs: forecasts and metrics

# %%
session2_forecasts = pd.read_csv("../src/data/session02_forecasts.csv", parse_dates=["Datetime"])
session2_results = pd.read_csv("../src/data/session02_results.csv")

session2_forecasts.head()
# Out:
#              Datetime   Actual  Prophet_Forecast  ETS_Forecast
# 0 2015-10-27 05:00:00  11779.0      12332.548904  11516.564108
# 1 2015-10-27 06:00:00  12583.0      12923.876391  11864.775038
# 2 2015-10-27 07:00:00  14032.0      13680.506232  12653.657278
# 3 2015-10-27 08:00:00  14867.0      14402.480455  13161.585886
# 4 2015-10-27 09:00:00  14837.0      14922.708629  12960.012023

# %%
session2_results
# Out:
#   Unnamed: 0       MAE      RMSE    MAPE     MPE
# 0    Prophet  1409.112  1810.041   9.520  -2.642
# 1        ETS  2701.305  3469.825  16.736  14.907

# %% [markdown]
# ### Session 3 outputs: comparison and interpretation metris

# %%
import json

# Session 3 expanded the model group to 7; load the canonical outputs
with open("../src/data/metrics_all_models.json") as f:
    session3_metrics = pd.DataFrame(json.load(f))

with open("../src/data/forecasts_all_models.json") as f:
    session3_forecasts = pd.DataFrame(json.load(f))

session3_metrics
# Out:
#                model     MAE    RMSE    MAPE     MPE     DA
# 0              Naive  781.31  948.15  5.4682  5.4343   0.00
# 1     Seasonal Naive  130.40  152.60  0.9289  0.8920  96.55
# 2  Linear Regression  483.29  547.70  3.4717 -0.0150  48.28
# 3                ETS   44.67   57.32  0.3199  0.0488  96.55
# 4      HWES (damped)   62.69   79.08  0.4478  0.4044  96.55
# 5             SARIMA   45.66   59.78  0.3258  0.1423  96.55
# 6            Prophet   89.01  112.18  0.6366  0.6106  96.55

# %%
session3_forecasts.head()
# Out:
#          date    actual  predicted  model
# 0  2020-12-01  13517.80   13149.53  Naive
# 1  2020-12-02  14261.68   13149.53  Naive
# 2  2020-12-03  14646.61   13149.53  Naive
# 3  2020-12-04  14445.82   13149.53  Naive
# 4  2020-12-05  13898.21   13149.53  Naive

# %% [markdown]
# ### Session 4 output: fuzzy labels

# %%
session4_labels = pd.read_csv("../src/data/session04_fuzzy_labels.csv")
session4_labels
# Out:
#                Model     MAE    RMSE   MAPE    MPE     DA     MAE_Label  \
# 0              Naive  781.31  948.15  5.468  5.434   0.00    high error
# 1     Seasonal Naive  130.40  152.60  0.929  0.892  96.55     low error
# 2  Linear Regression  483.29  547.70  3.472 -0.015  48.28  medium error
# 3                ETS   44.67   57.32  0.320  0.049  96.55     low error
# 4      HWES (damped)   62.69   79.08  0.448  0.404  96.55     low error
# 5             SARIMA   45.66   59.78  0.326  0.142  96.55     low error
# 6            Prophet   89.01  112.18  0.637  0.611  96.55     low error
#
#                MPE_Label                     Combined_Label
# 0  slight overprediction  high error, slight overprediction
# 1                neutral                 low error, neutral
# 2                neutral              medium error, neutral
# 3                neutral                 low error, neutral
# 4                neutral                 low error, neutral
# 5                neutral                 low error, neutral
# 6                neutral                 low error, neutral

# %% [markdown]
# ### Session 5 output: structured explanations

# %%
session5_structured = pd.read_csv("../src/data/session05_structured_explanations.csv")
session5_structured
# Out:
#                Model     MAE    RMSE   MAPE    MPE     DA     MAE_Label  \
# 0              Naive  781.31  948.15  5.468  5.434   0.00    high error
# 1     Seasonal Naive  130.40  152.60  0.929  0.892  96.55     low error
# 2  Linear Regression  483.29  547.70  3.472 -0.015  48.28  medium error
# 3                ETS   44.67   57.32  0.320  0.049  96.55     low error
# 4      HWES (damped)   62.69   79.08  0.448  0.404  96.55     low error
# 5             SARIMA   45.66   59.78  0.326  0.142  96.55     low error
# 6            Prophet   89.01  112.18  0.637  0.611  96.55     low error
#
#                MPE_Label                     Combined_Label  \
# 0  slight overprediction  high error, slight overprediction
# 1                neutral                 low error, neutral
# 2                neutral              medium error, neutral
# 3                neutral                 low error, neutral
# 4                neutral                 low error, neutral
# 5                neutral                 low error, neutral
# 6                neutral                 low error, neutral
#
#                               Structured_Explanation
# 0  The model has high error and tends to overpred...
# 1  The model is highly accurate and shows no cons...
# 2  The model has moderate error but no strong dir...
# 3  The model is highly accurate and shows no cons...
# 4  The model is highly accurate and shows no cons...
# 5  The model is highly accurate and shows no cons...
# 6  The model is highly accurate and shows no cons...

# %% [markdown]
# ### Session 6 output: final narratives

# %%
session6_narratives = pd.read_csv("../src/data/session06_narratives.csv")
session6_narratives
# Out:
#                Model     MAE    RMSE   MAPE    MPE     DA     MAE_Label  \
# 0              Naive  781.31  948.15  5.468  5.434   0.00    high error
# 1     Seasonal Naive  130.40  152.60  0.929  0.892  96.55     low error
# 2  Linear Regression  483.29  547.70  3.472 -0.015  48.28  medium error
# 3                ETS   44.67   57.32  0.320  0.049  96.55     low error
# 4      HWES (damped)   62.69   79.08  0.448  0.404  96.55     low error
# 5             SARIMA   45.66   59.78  0.326  0.142  96.55     low error
# 6            Prophet   89.01  112.18  0.637  0.611  96.55     low error
#
#                MPE_Label                     Combined_Label  \
# 0  slight overprediction  high error, slight overprediction
# 1                neutral                 low error, neutral
# 2                neutral              medium error, neutral
# 3                neutral                 low error, neutral
# 4                neutral                 low error, neutral
# 5                neutral                 low error, neutral
# 6                neutral                 low error, neutral
#
#                               Structured_Explanation  \
# 0  The model has high error and tends to overpred...
# 1  The model is highly accurate and shows no cons...
# 2  The model has moderate error but no strong dir...
# 3  The model is highly accurate and shows no cons...
# 4  The model is highly accurate and shows no cons...
# 5  The model is highly accurate and shows no cons...
# 6  The model is highly accurate and shows no cons...
#
#                                            Narrative
# 0  Naive is the weakest model in this comparison....
# 1  Seasonal Naive is one of the strongest models ...
# 2  Linear Regression shows moderate performance. ...
# 3  ETS is one of the strongest models in the comp...
# 4  HWES (damped) is one of the strongest models i...
# 5  SARIMA is one of the strongest models in the c...
# 6  Prophet is one of the strongest models in the ...

# %% [markdown]
# ## Compact Final Table

# %%
final_summary = session6_narratives[[
    "Model", "MAE", "RMSE", "MAPE", "MPE",
    "MAE_Label", "MPE_Label",
    "Structured_Explanation", "Narrative"
]]

final_summary
# Out:
#                Model     MAE    RMSE   MAPE    MPE     MAE_Label  \
# 0              Naive  781.31  948.15  5.468  5.434    high error
# 1     Seasonal Naive  130.40  152.60  0.929  0.892     low error
# 2  Linear Regression  483.29  547.70  3.472 -0.015  medium error
# 3                ETS   44.67   57.32  0.320  0.049     low error
# 4      HWES (damped)   62.69   79.08  0.448  0.404     low error
# 5             SARIMA   45.66   59.78  0.326  0.142     low error
# 6            Prophet   89.01  112.18  0.637  0.611     low error
#
#                MPE_Label                             Structured_Explanation  \
# 0  slight overprediction  The model has high error and tends to overpred...
# 1                neutral  The model is highly accurate and shows no cons...
# 2                neutral  The model has moderate error but no strong dir...
# 3                neutral  The model is highly accurate and shows no cons...
# 4                neutral  The model is highly accurate and shows no cons...
# 5                neutral  The model is highly accurate and shows no cons...
# 6                neutral  The model is highly accurate and shows no cons...
#
#                                            Narrative
# 0  Naive is the weakest model in this comparison....
# 1  Seasonal Naive is one of the strongest models ...
# 2  Linear Regression shows moderate performance. ...
# 3  ETS is one of the strongest models in the comp...
# 4  HWES (damped) is one of the strongest models i...
# 5  SARIMA is one of the strongest models in the c...
# 6  Prophet is one of the strongest models in the ...

# %%
final_summary.to_csv("../src/data/session07_full_pipeline_summary.csv", index=False)

# %%
for _, row in final_summary.iterrows():
    print(f"{row['Model']}: {row['Narrative']}")
    print()
# Out:
# Naive: Naive is the weakest model in this comparison. The model has high error and tends to overpredict demand. This suggests the forecasts are less accurate and tend to run above actual demand.
#
# Seasonal Naive: Seasonal Naive is one of the strongest models in the comparison. The model is highly accurate and shows no consistent directional bias. This suggests the model tracks electricity demand closely with minimal systematic error.
#
# Linear Regression: Linear Regression shows moderate performance. The model has moderate error but no strong directional bias. The error is noticeably larger than the best models, though the forecasts remain unbiased.
#
# ETS: ETS is one of the strongest models in the comparison. The model is highly accurate and shows no consistent directional bias. This suggests the model tracks electricity demand closely with minimal systematic error.
#
# HWES (damped): HWES (damped) is one of the strongest models in the comparison. The model is highly accurate and shows no consistent directional bias. This suggests the model tracks electricity demand closely with minimal systematic error.
#
# SARIMA: SARIMA is one of the strongest models in the comparison. The model is highly accurate and shows no consistent directional bias. This suggests the model tracks electricity demand closely with minimal systematic error.
#
# Prophet: Prophet is one of the strongest models in the comparison. The model is highly accurate and shows no consistent directional bias. This suggests the model tracks electricity demand closely with minimal systematic error.
